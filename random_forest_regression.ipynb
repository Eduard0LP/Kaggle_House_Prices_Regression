# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score, LeaveOneOut
import pickle

# %% [markdown]
# # 1. Load data

# %%
dataset = pd.read_csv('encoded_train_dataset.csv', sep = ',')

# %%
dataset
# Out:
#         Id  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        1         65.0   8450.0          7.0          5.0     2003.0
# 1        2         80.0   9600.0          6.0          8.0     1976.0
# 2        3         68.0  11250.0          7.0          5.0     2001.0
# 3        4         60.0   9550.0          7.0          5.0     1915.0
# 4        5         84.0  14260.0          8.0          5.0     2000.0
# ...    ...          ...      ...          ...          ...        ...
# 1455  1456         62.0   7917.0          6.0          5.0     1999.0
# 1456  1457         85.0  13175.0          6.0          6.0     1978.0
# 1457  1458         66.0   9042.0          7.0          9.0     1941.0
# 1458  1459         68.0   9717.0          5.0          6.0     1950.0
# 1459  1460         75.0   9937.0          5.0          6.0     1965.0
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  BsmtFinType2  \
# 0           2003.0       196.0       706.0         0.0  ...           1.0
# 1           1976.0         0.0       978.0         0.0  ...           1.0
# 2           2002.0       162.0       486.0         0.0  ...           1.0
# 3           1970.0         0.0       216.0         0.0  ...           1.0
# 4           2000.0       350.0       655.0         0.0  ...           1.0
# ...            ...         ...         ...         ...  ...           ...
# 1455        2000.0         0.0         0.0         0.0  ...           1.0
# 1456        1988.0       119.0       790.0       163.0  ...           3.0
# 1457        2006.0         0.0       275.0         0.0  ...           1.0
# 1458        1996.0         0.0        49.0      1029.0  ...           3.0
# 1459        1965.0         0.0       830.0       290.0  ...           2.0
#
#       HeatingQC  CentralAir  KitchenQual  FireplaceQu  GarageFinish  \
# 0           5.0         1.0          4.0          0.0           2.0
# 1           5.0         1.0          3.0          3.0           2.0
# 2           5.0         1.0          4.0          3.0           2.0
# 3           4.0         1.0          4.0          4.0           1.0
# 4           5.0         1.0          4.0          3.0           2.0
# ...         ...         ...          ...          ...           ...
# 1455        5.0         1.0          3.0          3.0           2.0
# 1456        3.0         1.0          3.0          3.0           1.0
# 1457        5.0         1.0          4.0          4.0           2.0
# 1458        4.0         1.0          4.0          0.0           1.0
# 1459        4.0         1.0          3.0          0.0           3.0
#
#       GarageQual  GarageCond  PavedDrive  PoolQC
# 0            3.0         3.0         2.0     0.0
# 1            3.0         3.0         2.0     0.0
# 2            3.0         3.0         2.0     0.0
# 3            3.0         3.0         2.0     0.0
# 4            3.0         3.0         2.0     0.0
# ...          ...         ...         ...     ...
# 1455         3.0         3.0         2.0     0.0
# 1456         3.0         3.0         2.0     0.0
# 1457         3.0         3.0         2.0     0.0
# 1458         3.0         3.0         2.0     0.0
# 1459         3.0         3.0         2.0     0.0
#
# [1460 rows x 258 columns]

# %% [markdown]
# # 2. Train the model and check accuracy

# %%
rfregressor = RandomForestRegressor()

# %%
X = dataset.drop(columns = ['SalePrice'])
y = dataset['SalePrice'].values

# %%
cv = LeaveOneOut()

# %%
scores = cross_val_score(rfregressor, X, y = y, scoring = 'neg_root_mean_squared_error', cv = cv)

# %%
-scores.mean()
# Out:
# 17354.036034246576

# %% [markdown]
# # 3. Fit the model

# %%
rfregressor.fit(X,y)
# Out:
# RandomForestRegressor()

# %% [markdown]
# # 4. Save the model

# %% [markdown]
# The fitted model is saved to a pickle file

# %%
with open('random_forest.pkl','wb') as f:
    pickle.dump(rfregressor,f)
